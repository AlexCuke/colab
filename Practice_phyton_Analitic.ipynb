# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexCuke/colab/blob/main/Practice_phyton_Analitic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
traty = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Информация о тратах.csv', sep=';',encoding='cp1251', usecols=range(6))
traty.head(10) #first 10 strings
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#       Отметка времени  Месяц Название операции  Сумма  Категория  \
# 0  11.7.2025 22:16:44      1           завтрак     18        еда
# 1  11.7.2025 22:16:54      2              ужин     27        еда
# 2  11.7.2025 22:17:06      3              обед     23        еда
# 3  11.7.2025 22:17:22      4        электричка     54  транспорт
# 4  11.7.2025 22:17:31      5           подарок     23     другое
# 5  11.7.2025 22:17:44      7              обед     45        еда
# 6  11.7.2025 22:17:58      8              ужин     34        еда
# 7  11.7.2025 22:18:07      9            платье     43     одежда
# 8  11.7.2025 22:18:19     10            джинсы     32     одежда
# 9  11.7.2025 22:18:30     11            отпуск     65     другое
#
#   Регулярные траты
# 0           ИСТИНА
# 1           ИСТИНА
# 2           ИСТИНА
# 3             ЛОЖЬ
# ...

# %%
traty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Отметка времени    21 non-null     object
#  1   Месяц              21 non-null     int64
#  2   Название операции  21 non-null     object
#  3   Сумма              21 non-null     int64
#  4   Категория          21 non-null     object
#  5   Регулярные траты   21 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %%
traty.describe()
# Out:
#            Месяц      Сумма
# count  21.000000  21.000000
# mean    6.714286  38.333333
# std     3.211586  12.997436
# min     1.000000  12.000000
# 25%     4.000000  32.000000
# 50%     7.000000  43.000000
# 75%     9.000000  45.000000
# max    12.000000  65.000000

# %%
traty.groupby('Категория').sum('Сумма')
# Out:
#            Месяц  Сумма
# Категория
# другое        34    199
# еда           43    202
# одежда        36    217
# транспорт     28    187
